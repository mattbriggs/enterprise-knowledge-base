# %% [markdown]
# # ETL Demo
#
# This notebook mirrors the first implementation slice in `oks.etl`.
#
# It focuses on three operations:
#
# - parsing YAML front matter
# - chunking Markdown by level-two headings
# - building normalized records for downstream use

# %%
from pathlib import Path

from oks.etl import extract_chunks_from_file

sample_path = Path("content/01_introduction.md")
chunks = extract_chunks_from_file(sample_path)
len(chunks), chunks[0]["heading"]

# %%
chunks[0]
